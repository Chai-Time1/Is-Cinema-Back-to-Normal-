# %% [markdown]
# # **Using pandas read_html to Web Scrape Data for Data Science**
#
# Tarun Badarvada
#
# <i>[Data Professor YouTube channel](http://youtube.com/dataprofessor), http://youtube.com/dataprofessor </i>
#
# In this Jupyter notebook, I will be showing you how to easily web scrape data using pandas read_html() function for your data science project. We will be web scraping BoxOfficeMojo data and perform a quick data exploration.

# %% [markdown]
# ## **URL to the webpage "Box Offce Data from Box Office Mojo"**

# %% [markdown]
# ### Method 1
#
# We could modularize the URL and year strings of text that may be useful for programmatic access (in the subsequent code cell).

# %%
# The Building Blocks
url = 'https://www.boxofficemojo.com/weekend/by-year/2022/'

# Combining the URL + year strings together
url
# Out:
# 'https://www.boxofficemojo.com/weekend/by-year/2022/'

# %% [markdown]
# ## **Read HTML webpage into pandas**

# %%
import pandas as pd

# %% [markdown]
# ### Using pd.read_html() function to read HTML webpage

# %%
df = pd.read_html(url, header = 0)
df
# Out:
# [                               Dates  Top 10 Gross    %± LW Overall Gross  \
#  0                          Oct 28-30   $63,561,374   -42.3%   $67,714,988
#  1                          Oct 21-23  $110,164,317   +51.5%  $113,640,500
#  2                          Oct 14-16   $72,697,268   +35.2%   $76,320,215
#  3   Oct 7-10Indig. Peoples' Day wknd   $61,664,865   -49.1%   $67,232,636
#  4                            Oct 7-9   $53,759,907    -5.3%   $58,948,341
#  5                       Sep 30-Oct 2   $56,765,793    +1.8%   $63,913,605
#  6                          Sep 23-25   $55,769,690   +29.5%   $62,422,437
#  7                          Sep 16-18   $43,050,766   +26.8%   $51,461,085
#  8                           Sep 9-11   $33,945,638   -19.9%   $43,193,037
#  9              Sep 2-5Labor Day wknd   $54,205,807   -60.1%   $71,172,772
#  10                           Sep 2-4   $42,395,247    +2.4%   $55,664,136
#  11                         Aug 26-28   $41,408,038   -40.2%   $52,149,690
#  12                         Aug 19-21   $69,281,199     +25%   $78,931,261
#  13                         Aug 12-14   $55,432,709     -37%   $65,392,243
#  14                           Aug 5-7   $88,004,513    -6.2%   $92,090,558
#  15                         Jul 29-31   $93,856,999   -24.4%   $97,884,255
#  16                         Jul 22-24  $124,080,435    -5.4%  $126,239,585
#  17                         Jul 15-17  $131,231,157   -44.7%  $132,813,074
#  18                          Jul 8-10  $237,265,821   +25.9%  $238,358,457
#  19                           Jul 1-3  $188,498,988   +41.4%  $189,927,071
#  20         Jul 1-4July 4th long wknd  $221,928,586  +162.8%  $223,580,059
#  21                         Jun 24-26  $133,333,162   -18.3%  $134,597,965
#  22                         Jun 17-19  $163,242,107   -23.1%  $164,531,244
#  23                         Jun 10-12  $212,413,470   +79.4%  $214,852,641
#  24                           Jun 3-5  $118,392,908   -32.2%  $121,670,007
#  25                         May 27-29  $174,602,102  +144.1%  $177,208,035
#  26        May 27-30Memorial Day wknd  $220,038,783  +128.9%  $223,364,859
#  27                         May 20-22   $71,518,782   -19.7%   $75,659,163
#  28                         May 13-15   $89,049,541   -59.6%   $91,763,058
#  29                           May 6-8  $220,282,059  +252.4%  $222,333,899
#  30                      Apr 29-May 1   $62,512,297   -30.7%   $66,904,036
#  31                         Apr 22-24   $90,218,714   -14.8%   $93,504,011
#  32                         Apr 15-17  $105,898,267    -9.6%  $107,172,204
#  33              Apr 15-18Easter wknd  $118,286,160  +153.6%  $119,502,673
#  34                          Apr 8-10  $117,176,203   +52.5%  $118,700,008
#  35                           Apr 1-3   $76,848,023    -2.1%   $79,620,169
#  36                         Mar 25-27   $78,479,529      -2%   $82,024,556
#  37                         Mar 18-20   $80,060,996   -19.4%   $83,455,041
#  38                         Mar 11-13   $99,316,599   -39.2%  $101,939,737
#  39                           Mar 4-6  $163,405,808  +197.1%  $166,054,235
#  40                         Feb 25-27   $55,006,939     -39%   $60,894,360
#  41     Feb 18-21Presidents' Day wknd  $106,169,516  +784.3%  $111,431,414
#  42                         Feb 18-20   $90,159,064     +79%   $94,565,238
#  43                         Feb 11-13   $50,371,632    -9.8%   $53,803,427
#  44                           Feb 4-6   $55,860,817   +81.4%   $59,689,505
#  45                         Jan 28-30   $30,794,469     -27%   $34,885,910
#  46                         Jan 21-23   $42,161,017   -38.3%   $46,071,484
#  47                         Jan 14-16   $68,339,319   +13.3%   $71,534,496
#  48                 Jan 14-17MLK wknd   $81,219,405  +549.9%   $85,074,757
#  49                           Jan 7-9   $60,318,053     -37%   $62,796,729
#
#      %± LW.1  Releases                                   #1 Release Genre  \
#  0    -40.4%        49                                   Black Adam     -
#  1    +48.9%        53                                   Black Adam     -
#  2    +29.5%        53                               Halloween Ends     -
#  3    -45.1%        44                                        Smile     -
#  4     -7.8%        65                                        Smile     -
#  5     +2.4%        68                                        Smile     -
#  6    +21.3%        70                          Don't Worry Darling     -
#  7    +19.1%        74                               The Woman King     -
#  8    -22.4%        69                                    Barbarian     -
#  9    -48.8%        55                            Top Gun: Maverick     -
#  10    +6.7%        63                            Top Gun: Maverick     -
#  11   -33.9%        64                               The Invitation     -
#  12   +20.7%        58                Dragon Ball Super: Super Hero     -
#  13     -29%        63                                 Bullet Train     -
#  14    -5.9%        48                                 Bullet Train     -
#  15   -22.5%        53                      DC League of Super-Pets     -
#  16    -4.9%        52                                         Nope     -
#  17   -44.3%        54                       Thor: Love and Thunder     -
#  18   +25.5%        50                       Thor: Love and Thunder     -
#  19   +41.1%        53                     Minions: The Rise of Gru     -
#  20  +156.5%        40                     Minions: The Rise of Gru     -
#  21   -18.2%        54                                        Elvis     -
#  22   -23.4%        56                      Jurassic World Dominion     -
#  23   +76.6%        56                      Jurassic World Dominion     -
#  24   -31.3%        59                            Top Gun: Maverick     -
#  25  +134.2%        50                            Top Gun: Maverick     -
#  26  +128.2%        47                            Top Gun: Maverick     -
#  27   -17.5%        53  Doctor Strange in the Multiverse of Madness     -
#  28   -58.7%        49  Doctor Strange in the Multiverse of Madness     -
#  29  +232.3%        45  Doctor Strange in the Multiverse of Madness     -
#  30   -28.4%        50                                 The Bad Guys     -
#  31   -12.8%        46                                 The Bad Guys     -
#  32    -9.7%        42  Fantastic Beasts: The Secrets of Dumbledore     -
#  33  +151.5%        30  Fantastic Beasts: The Secrets of Dumbledore     -
#  34   +49.1%        50                         Sonic the Hedgehog 2     -
#  35    -2.9%        52                                      Morbius     -
#  36    -1.7%        59                                The Lost City     -
#  37   -18.1%        58                                   The Batman     -
#  38   -38.6%        53                                   The Batman     -
#  39  +172.7%        54                                   The Batman     -
#  40   -35.6%        53                                    Uncharted     -
#  41  +748.5%        50                                    Uncharted     -
#  42   +75.8%        51                                    Uncharted     -
#  43    -9.9%        51                            Death on the Nile     -
#  44   +71.1%        51                              Jackass Forever     -
#  45   -24.3%        47                      Spider-Man: No Way Home     -
#  46   -35.6%        44                      Spider-Man: No Way Home     -
#  47   +13.9%        41                                       Scream     -
#  48  +559.1%        37                                       Scream     -
#  49   -36.5%        35                      Spider-Man: No Way Home     -
#
#     Budget Running Time  Week  Long Weekend
#  0       -            -    43         False
#  1       -            -    42         False
#  2       -            -    41         False
#  3       -            -    40          True
#  4       -            -    40         False
#  5       -            -    39         False
#  6       -            -    38         False
#  7       -            -    37         False
#  8       -            -    36         False
#  9       -            -    35          True
#  10      -            -    35         False
#  11      -            -    34         False
#  12      -            -    33         False
#  13      -            -    32         False
#  14      -            -    31         False
#  15      -            -    30         False
#  16      -            -    29         False
#  17      -            -    28         False
#  18      -            -    27         False
#  19      -            -    26         False
#  20      -            -    26          True
#  21      -            -    25         False
#  22      -            -    24         False
#  23      -            -    23         False
#  24      -            -    22         False
#  25      -            -    21         False
#  26      -            -    21          True
#  27      -            -    20         False
#  28      -            -    19         False
#  29      -            -    18         False
#  30      -            -    17         False
#  31      -            -    16         False
#  32      -            -    15         False
#  33      -            -    15          True
#  34      -            -    14         False
#  35      -            -    13         False
#  36      -            -    12         False
#  37      -            -    11         False
#  38      -            -    10         False
#  39      -            -     9         False
#  40      -            -     8         False
#  41      -            -     7          True
#  42      -            -     7         False
#  43      -            -     6         False
#  44      -            -     5         False
#  45      -            -     4         False
#  46      -            -     3         False
#  47      -            -     2         False
#  48      -            -     2          True
#  49      -            -     1         False  ]

# %% [markdown]
# ### How many tables are there in the webpage?

# %%
len(df)
# Out:
# 1

# %% [markdown]
# ### Select the first table

# %%
df[0]
# Out:
#                                Dates  Top 10 Gross    %± LW Overall Gross  \
# 0                          Oct 28-30   $63,561,374   -42.3%   $67,714,988
# 1                          Oct 21-23  $110,164,317   +51.5%  $113,640,500
# 2                          Oct 14-16   $72,697,268   +35.2%   $76,320,215
# 3   Oct 7-10Indig. Peoples' Day wknd   $61,664,865   -49.1%   $67,232,636
# 4                            Oct 7-9   $53,759,907    -5.3%   $58,948,341
# 5                       Sep 30-Oct 2   $56,765,793    +1.8%   $63,913,605
# 6                          Sep 23-25   $55,769,690   +29.5%   $62,422,437
# 7                          Sep 16-18   $43,050,766   +26.8%   $51,461,085
# 8                           Sep 9-11   $33,945,638   -19.9%   $43,193,037
# 9              Sep 2-5Labor Day wknd   $54,205,807   -60.1%   $71,172,772
# 10                           Sep 2-4   $42,395,247    +2.4%   $55,664,136
# 11                         Aug 26-28   $41,408,038   -40.2%   $52,149,690
# 12                         Aug 19-21   $69,281,199     +25%   $78,931,261
# 13                         Aug 12-14   $55,432,709     -37%   $65,392,243
# 14                           Aug 5-7   $88,004,513    -6.2%   $92,090,558
# 15                         Jul 29-31   $93,856,999   -24.4%   $97,884,255
# 16                         Jul 22-24  $124,080,435    -5.4%  $126,239,585
# 17                         Jul 15-17  $131,231,157   -44.7%  $132,813,074
# 18                          Jul 8-10  $237,265,821   +25.9%  $238,358,457
# 19                           Jul 1-3  $188,498,988   +41.4%  $189,927,071
# 20         Jul 1-4July 4th long wknd  $221,928,586  +162.8%  $223,580,059
# 21                         Jun 24-26  $133,333,162   -18.3%  $134,597,965
# 22                         Jun 17-19  $163,242,107   -23.1%  $164,531,244
# 23                         Jun 10-12  $212,413,470   +79.4%  $214,852,641
# 24                           Jun 3-5  $118,392,908   -32.2%  $121,670,007
# 25                         May 27-29  $174,602,102  +144.1%  $177,208,035
# 26        May 27-30Memorial Day wknd  $220,038,783  +128.9%  $223,364,859
# 27                         May 20-22   $71,518,782   -19.7%   $75,659,163
# 28                         May 13-15   $89,049,541   -59.6%   $91,763,058
# 29                           May 6-8  $220,282,059  +252.4%  $222,333,899
# 30                      Apr 29-May 1   $62,512,297   -30.7%   $66,904,036
# 31                         Apr 22-24   $90,218,714   -14.8%   $93,504,011
# 32                         Apr 15-17  $105,898,267    -9.6%  $107,172,204
# 33              Apr 15-18Easter wknd  $118,286,160  +153.6%  $119,502,673
# 34                          Apr 8-10  $117,176,203   +52.5%  $118,700,008
# 35                           Apr 1-3   $76,848,023    -2.1%   $79,620,169
# 36                         Mar 25-27   $78,479,529      -2%   $82,024,556
# 37                         Mar 18-20   $80,060,996   -19.4%   $83,455,041
# 38                         Mar 11-13   $99,316,599   -39.2%  $101,939,737
# 39                           Mar 4-6  $163,405,808  +197.1%  $166,054,235
# 40                         Feb 25-27   $55,006,939     -39%   $60,894,360
# 41     Feb 18-21Presidents' Day wknd  $106,169,516  +784.3%  $111,431,414
# 42                         Feb 18-20   $90,159,064     +79%   $94,565,238
# 43                         Feb 11-13   $50,371,632    -9.8%   $53,803,427
# 44                           Feb 4-6   $55,860,817   +81.4%   $59,689,505
# 45                         Jan 28-30   $30,794,469     -27%   $34,885,910
# 46                         Jan 21-23   $42,161,017   -38.3%   $46,071,484
# 47                         Jan 14-16   $68,339,319   +13.3%   $71,534,496
# 48                 Jan 14-17MLK wknd   $81,219,405  +549.9%   $85,074,757
# 49                           Jan 7-9   $60,318,053     -37%   $62,796,729
#
#     %± LW.1  Releases                                   #1 Release Genre  \
# 0    -40.4%        49                                   Black Adam     -
# 1    +48.9%        53                                   Black Adam     -
# 2    +29.5%        53                               Halloween Ends     -
# 3    -45.1%        44                                        Smile     -
# 4     -7.8%        65                                        Smile     -
# 5     +2.4%        68                                        Smile     -
# 6    +21.3%        70                          Don't Worry Darling     -
# 7    +19.1%        74                               The Woman King     -
# 8    -22.4%        69                                    Barbarian     -
# 9    -48.8%        55                            Top Gun: Maverick     -
# 10    +6.7%        63                            Top Gun: Maverick     -
# 11   -33.9%        64                               The Invitation     -
# 12   +20.7%        58                Dragon Ball Super: Super Hero     -
# 13     -29%        63                                 Bullet Train     -
# 14    -5.9%        48                                 Bullet Train     -
# 15   -22.5%        53                      DC League of Super-Pets     -
# 16    -4.9%        52                                         Nope     -
# 17   -44.3%        54                       Thor: Love and Thunder     -
# 18   +25.5%        50                       Thor: Love and Thunder     -
# 19   +41.1%        53                     Minions: The Rise of Gru     -
# 20  +156.5%        40                     Minions: The Rise of Gru     -
# 21   -18.2%        54                                        Elvis     -
# 22   -23.4%        56                      Jurassic World Dominion     -
# 23   +76.6%        56                      Jurassic World Dominion     -
# 24   -31.3%        59                            Top Gun: Maverick     -
# 25  +134.2%        50                            Top Gun: Maverick     -
# 26  +128.2%        47                            Top Gun: Maverick     -
# 27   -17.5%        53  Doctor Strange in the Multiverse of Madness     -
# 28   -58.7%        49  Doctor Strange in the Multiverse of Madness     -
# 29  +232.3%        45  Doctor Strange in the Multiverse of Madness     -
# 30   -28.4%        50                                 The Bad Guys     -
# 31   -12.8%        46                                 The Bad Guys     -
# 32    -9.7%        42  Fantastic Beasts: The Secrets of Dumbledore     -
# 33  +151.5%        30  Fantastic Beasts: The Secrets of Dumbledore     -
# 34   +49.1%        50                         Sonic the Hedgehog 2     -
# 35    -2.9%        52                                      Morbius     -
# 36    -1.7%        59                                The Lost City     -
# 37   -18.1%        58                                   The Batman     -
# 38   -38.6%        53                                   The Batman     -
# 39  +172.7%        54                                   The Batman     -
# 40   -35.6%        53                                    Uncharted     -
# 41  +748.5%        50                                    Uncharted     -
# 42   +75.8%        51                                    Uncharted     -
# 43    -9.9%        51                            Death on the Nile     -
# 44   +71.1%        51                              Jackass Forever     -
# 45   -24.3%        47                      Spider-Man: No Way Home     -
# 46   -35.6%        44                      Spider-Man: No Way Home     -
# 47   +13.9%        41                                       Scream     -
# 48  +559.1%        37                                       Scream     -
# 49   -36.5%        35                      Spider-Man: No Way Home     -
#
#    Budget Running Time  Week  Long Weekend
# 0       -            -    43         False
# 1       -            -    42         False
# 2       -            -    41         False
# 3       -            -    40          True
# 4       -            -    40         False
# 5       -            -    39         False
# 6       -            -    38         False
# 7       -            -    37         False
# 8       -            -    36         False
# 9       -            -    35          True
# 10      -            -    35         False
# 11      -            -    34         False
# 12      -            -    33         False
# 13      -            -    32         False
# 14      -            -    31         False
# 15      -            -    30         False
# 16      -            -    29         False
# 17      -            -    28         False
# 18      -            -    27         False
# 19      -            -    26         False
# 20      -            -    26          True
# 21      -            -    25         False
# 22      -            -    24         False
# 23      -            -    23         False
# 24      -            -    22         False
# 25      -            -    21         False
# 26      -            -    21          True
# 27      -            -    20         False
# 28      -            -    19         False
# 29      -            -    18         False
# 30      -            -    17         False
# 31      -            -    16         False
# 32      -            -    15         False
# 33      -            -    15          True
# 34      -            -    14         False
# 35      -            -    13         False
# 36      -            -    12         False
# 37      -            -    11         False
# 38      -            -    10         False
# 39      -            -     9         False
# 40      -            -     8         False
# 41      -            -     7          True
# 42      -            -     7         False
# 43      -            -     6         False
# 44      -            -     5         False
# 45      -            -     4         False
# 46      -            -     3         False
# 47      -            -     2         False
# 48      -            -     2          True
# 49      -            -     1         False

# %%
df2022 = df[0]

# %%
df2022.drop('Genre', inplace = True,axis = 1)

# %%
df2022.drop('Budget', inplace = True,axis = 1)

# %%
df2022.drop('Running Time', inplace = True,axis = 1)

# %%
df2022['Top 10 Gross'] = df2022['Top 10 Gross'].str.replace('\W','')
# Out:
# /var/folders/k5/kq4wgns12dn1k2v1k48nckdc0000gn/T/ipykernel_42062/1489840082.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   df2022['Top 10 Gross'] = df2022['Top 10 Gross'].str.replace('\W','')

# %%
df2022['Top 10 Gross'] = df2022['Top 10 Gross'].astype('int64')

# %%
df2022['Top 10 Gross']
# Out:
# 0      63561374
# 1     110164317
# 2      72697268
# 3      61664865
# 4      53759907
# 5      56765793
# 6      55769690
# 7      43050766
# 8      33945638
# 9      54205807
# 10     42395247
# 11     41408038
# 12     69281199
# 13     55432709
# 14     88004513
# 15     93856999
# 16    124080435
# 17    131231157
# 18    237265821
# 19    188498988
# 20    221928586
# 21    133333162
# 22    163242107
# 23    212413470
# 24    118392908
# 25    174602102
# 26    220038783
# 27     71518782
# 28     89049541
# 29    220282059
# 30     62512297
# 31     90218714
# 32    105898267
# 33    118286160
# 34    117176203
# 35     76848023
# 36     78479529
# 37     80060996
# 38     99316599
# 39    163405808
# 40     55006939
# 41    106169516
# 42     90159064
# 43     50371632
# 44     55860817
# 45     30794469
# 46     42161017
# 47     68339319
# 48     81219405
# 49     60318053
# Name: Top 10 Gross, dtype: int64

# %%
df2022.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Dates          50 non-null     object
#  1   Top 10 Gross   50 non-null     int64
#  2   %± LW          50 non-null     object
#  3   Overall Gross  50 non-null     object
#  4   %± LW.1        50 non-null     object
#  5   Releases       50 non-null     int64
#  6   #1 Release     50 non-null     object
#  7   Week           50 non-null     int64
#  8   Long Weekend   50 non-null     bool
# dtypes: bool(1), int64(3), object(5)
# memory usage: 3.3+ KB

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# We can see that the table header is presented multiple times in several rows.

# %%
df2022[df2022.Releases == 'Releases']
# Out:
# Empty DataFrame
# Columns: [Dates, Top 10 Gross, %± LW, Overall Gross, %± LW.1, Releases, #1 Release, Week, Long Weekend]
# Index: []

# %%
df2022.shape
# Out:
# (50, 9)

# %%
len(df2022[df2022.Releases == 'Releases'])
# Out:
# 0

# %%
df = df2022.drop(df2022[df2022.Releases == 'Releases'].index)

# %%
df.shape
# Out:
# (50, 9)

# %% [markdown]
# ## Quick Exploratory Data Analysis

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Making the Line Plot of # of Releases during 2022

# %%
sns.lineplot(data = df2022, x = 'Week', y = 'Releases')
# Out:
# <AxesSubplot: xlabel='Week', ylabel='Releases'>

# %% [markdown]
# Plotted Line graph of Top 10 Gross vs. Weeks

# %%
plt.plot(df2022['Week'],df2022['Top 10 Gross'])
plt.show()

# %%
#Save data fram to csv

df2022.to_csv('data2022.csv')

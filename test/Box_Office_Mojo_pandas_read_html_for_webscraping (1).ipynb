# %% [markdown]
# # **Using pandas read_html to Web Scrape Data for Data Science**
#
# Chanin Nantasenamat
#
# <i>[Data Professor YouTube channel](http://youtube.com/dataprofessor), http://youtube.com/dataprofessor </i>
#
# In this Jupyter notebook, I will be showing you how to easily web scrape data using pandas read_html() function for your data science project. We will be web scraping NBA player stats data and perform a quick data exploration.

# %% [markdown]
# ## **URL to the webpage "Box Offce Data from Box Office Mojo"**

# %% [markdown]
# ### Method 1
#
# We could modularize the URL and year strings of text that may be useful for programmatic access (in the subsequent code cell).

# %%
# The Building Blocks
url = 'https://www.boxofficemojo.com/weekend/?ref_=bo_nb_di_secondarytab'

# Combining the URL + year strings together
url
# Out:
# 'https://www.boxofficemojo.com/weekend/?ref_=bo_nb_di_secondarytab'

# %% [markdown]
# ## **Read HTML webpage into pandas**

# %%
import pandas as pd

# %% [markdown]
# ### Using pd.read_html() function to read HTML webpage

# %%
df = pd.read_html(url, header = 0)
df
# Out:
# [                            Dates  Top 10 Gross    %± LW Overall Gross  \
#  0                       Sep 23-25   $55,143,494        -   $59,740,078
#  1                       Sep 16-18   $43,050,766   +26.8%   $51,038,833
#  2                        Sep 9-11   $33,945,638   -19.9%   $42,296,737
#  3           Sep 2-5Labor Day wknd   $53,955,644   -60.3%   $70,907,770
#  4                         Sep 2-4   $42,368,538    +2.3%   $55,647,356
#  5                       Aug 26-28   $41,406,043   -40.2%   $52,143,709
#  6                       Aug 19-21   $69,278,329     +25%   $78,927,736
#  7                       Aug 12-14   $55,432,709     -37%   $65,386,421
#  8                         Aug 5-7   $88,004,513    -6.2%   $92,090,558
#  9                       Jul 29-31   $93,856,999   -24.4%   $97,884,255
#  10                      Jul 22-24  $124,080,435    -5.4%  $126,239,585
#  11                      Jul 15-17  $131,231,157   -44.7%  $132,813,074
#  12                       Jul 8-10  $237,265,821   +25.9%  $238,358,457
#  13      Jul 1-4July 4th long wknd  $221,928,586  +162.8%  $223,580,059
#  14                        Jul 1-3  $188,498,988   +41.4%  $189,927,071
#  15                      Jun 24-26  $133,333,162   -18.3%  $134,597,965
#  16                      Jun 17-19  $163,242,107   -23.1%  $164,531,244
#  17                      Jun 10-12  $212,413,470   +79.4%  $214,852,641
#  18                        Jun 3-5  $118,392,908   -32.2%  $121,670,007
#  19     May 27-30Memorial Day wknd  $220,038,783  +128.9%  $223,364,859
#  20                      May 27-29  $174,602,102  +144.1%  $177,208,035
#  21                      May 20-22   $71,518,782   -19.7%   $75,659,163
#  22                      May 13-15   $89,049,541   -59.6%   $91,763,058
#  23                        May 6-8  $220,282,059  +252.4%  $222,333,899
#  24                   Apr 29-May 1   $62,512,297   -30.7%   $66,904,036
#  25                      Apr 22-24   $90,218,714   -14.8%   $93,504,011
#  26           Apr 15-18Easter wknd  $118,286,160  +153.6%  $119,502,673
#  27                      Apr 15-17  $105,898,267    -9.6%  $107,172,204
#  28                       Apr 8-10  $117,176,203   +52.5%  $118,700,008
#  29                        Apr 1-3   $76,848,023    -2.1%   $79,620,169
#  30                      Mar 25-27   $78,479,529      -2%   $82,024,556
#  31                      Mar 18-20   $80,060,996   -19.4%   $83,455,041
#  32                      Mar 11-13   $99,316,599   -39.2%  $101,939,737
#  33                        Mar 4-6  $163,405,808  +197.1%  $166,054,235
#  34                      Feb 25-27   $55,006,939     -39%   $60,894,360
#  35  Feb 18-21Presidents' Day wknd  $106,169,516  +784.3%  $111,431,414
#  36                      Feb 18-20   $90,159,064     +79%   $94,565,238
#  37                      Feb 11-13   $50,371,632    -9.8%   $53,803,427
#  38                        Feb 4-6   $55,860,817   +81.4%   $59,689,505
#  39                      Jan 28-30   $30,794,469     -27%   $34,885,910
#  40                      Jan 21-23   $42,161,017   -38.3%   $46,071,484
#  41                      Jan 14-16   $68,339,319   +13.3%   $71,534,496
#  42              Jan 14-17MLK wknd   $81,219,405  +549.9%   $85,074,757
#  43                        Jan 7-9   $60,318,053     -37%   $62,796,729
#
#      %± LW.1  Releases                                   #1 Release Genre  \
#  0         -        29                          Don't Worry Darling     -
#  1    +20.7%        69                               The Woman King     -
#  2      -24%        66                                    Barbarian     -
#  3      -49%        54                            Top Gun: Maverick     -
#  4     +6.7%        61                            Top Gun: Maverick     -
#  5    -33.9%        63                               The Invitation     -
#  6    +20.7%        57                Dragon Ball Super: Super Hero     -
#  7      -29%        63                                 Bullet Train     -
#  8     -5.9%        48                                 Bullet Train     -
#  9    -22.5%        53                      DC League of Super-Pets     -
#  10    -4.9%        52                                         Nope     -
#  11   -44.3%        54                       Thor: Love and Thunder     -
#  12   +25.5%        50                       Thor: Love and Thunder     -
#  13  +156.5%        40                     Minions: The Rise of Gru     -
#  14   +41.1%        53                     Minions: The Rise of Gru     -
#  15   -18.2%        54                                        Elvis     -
#  16   -23.4%        56                      Jurassic World Dominion     -
#  17   +76.6%        56                      Jurassic World Dominion     -
#  18   -31.3%        59                            Top Gun: Maverick     -
#  19  +128.2%        47                            Top Gun: Maverick     -
#  20  +134.2%        50                            Top Gun: Maverick     -
#  21   -17.5%        53  Doctor Strange in the Multiverse of Madness     -
#  22   -58.7%        49  Doctor Strange in the Multiverse of Madness     -
#  23  +232.3%        45  Doctor Strange in the Multiverse of Madness     -
#  24   -28.4%        50                                 The Bad Guys     -
#  25   -12.8%        46                                 The Bad Guys     -
#  26  +151.5%        30  Fantastic Beasts: The Secrets of Dumbledore     -
#  27    -9.7%        42  Fantastic Beasts: The Secrets of Dumbledore     -
#  28   +49.1%        50                         Sonic the Hedgehog 2     -
#  29    -2.9%        52                                      Morbius     -
#  30    -1.7%        59                                The Lost City     -
#  31   -18.1%        58                                   The Batman     -
#  32   -38.6%        53                                   The Batman     -
#  33  +172.7%        54                                   The Batman     -
#  34   -35.6%        53                                    Uncharted     -
#  35  +748.5%        50                                    Uncharted     -
#  36   +75.8%        51                                    Uncharted     -
#  37    -9.9%        51                            Death on the Nile     -
#  38   +71.1%        51                              Jackass Forever     -
#  39   -24.3%        47                      Spider-Man: No Way Home     -
#  40   -35.6%        44                      Spider-Man: No Way Home     -
#  41   +13.9%        41                                       Scream     -
#  42  +559.1%        37                                       Scream     -
#  43   -36.5%        35                      Spider-Man: No Way Home     -
#
#     Budget Running Time  Week  Long Weekend
#  0       -            -    38         False
#  1       -            -    37         False
#  2       -            -    36         False
#  3       -            -    35          True
#  4       -            -    35         False
#  5       -            -    34         False
#  6       -            -    33         False
#  7       -            -    32         False
#  8       -            -    31         False
#  9       -            -    30         False
#  10      -            -    29         False
#  11      -            -    28         False
#  12      -            -    27         False
#  13      -            -    26          True
#  14      -            -    26         False
#  15      -            -    25         False
#  16      -            -    24         False
#  17      -            -    23         False
#  18      -            -    22         False
#  19      -            -    21          True
#  20      -            -    21         False
#  21      -            -    20         False
#  22      -            -    19         False
#  23      -            -    18         False
#  24      -            -    17         False
#  25      -            -    16         False
#  26      -            -    15          True
#  27      -            -    15         False
#  28      -            -    14         False
#  29      -            -    13         False
#  30      -            -    12         False
#  31      -            -    11         False
#  32      -            -    10         False
#  33      -            -     9         False
#  34      -            -     8         False
#  35      -            -     7          True
#  36      -            -     7         False
#  37      -            -     6         False
#  38      -            -     5         False
#  39      -            -     4         False
#  40      -            -     3         False
#  41      -            -     2         False
#  42      -            -     2          True
#  43      -            -     1         False  ]

# %% [markdown]
# ### How many tables are there in the webpage?

# %%
len(df)
# Out:
# 1

# %% [markdown]
# ### Select the first table

# %%
df[0]
# Out:
#                             Dates  Top 10 Gross    %± LW Overall Gross  \
# 0                       Sep 23-25   $55,143,494        -   $59,740,078
# 1                       Sep 16-18   $43,050,766   +26.8%   $51,038,833
# 2                        Sep 9-11   $33,945,638   -19.9%   $42,296,737
# 3           Sep 2-5Labor Day wknd   $53,955,644   -60.3%   $70,907,770
# 4                         Sep 2-4   $42,368,538    +2.3%   $55,647,356
# 5                       Aug 26-28   $41,406,043   -40.2%   $52,143,709
# 6                       Aug 19-21   $69,278,329     +25%   $78,927,736
# 7                       Aug 12-14   $55,432,709     -37%   $65,386,421
# 8                         Aug 5-7   $88,004,513    -6.2%   $92,090,558
# 9                       Jul 29-31   $93,856,999   -24.4%   $97,884,255
# 10                      Jul 22-24  $124,080,435    -5.4%  $126,239,585
# 11                      Jul 15-17  $131,231,157   -44.7%  $132,813,074
# 12                       Jul 8-10  $237,265,821   +25.9%  $238,358,457
# 13      Jul 1-4July 4th long wknd  $221,928,586  +162.8%  $223,580,059
# 14                        Jul 1-3  $188,498,988   +41.4%  $189,927,071
# 15                      Jun 24-26  $133,333,162   -18.3%  $134,597,965
# 16                      Jun 17-19  $163,242,107   -23.1%  $164,531,244
# 17                      Jun 10-12  $212,413,470   +79.4%  $214,852,641
# 18                        Jun 3-5  $118,392,908   -32.2%  $121,670,007
# 19     May 27-30Memorial Day wknd  $220,038,783  +128.9%  $223,364,859
# 20                      May 27-29  $174,602,102  +144.1%  $177,208,035
# 21                      May 20-22   $71,518,782   -19.7%   $75,659,163
# 22                      May 13-15   $89,049,541   -59.6%   $91,763,058
# 23                        May 6-8  $220,282,059  +252.4%  $222,333,899
# 24                   Apr 29-May 1   $62,512,297   -30.7%   $66,904,036
# 25                      Apr 22-24   $90,218,714   -14.8%   $93,504,011
# 26           Apr 15-18Easter wknd  $118,286,160  +153.6%  $119,502,673
# 27                      Apr 15-17  $105,898,267    -9.6%  $107,172,204
# 28                       Apr 8-10  $117,176,203   +52.5%  $118,700,008
# 29                        Apr 1-3   $76,848,023    -2.1%   $79,620,169
# 30                      Mar 25-27   $78,479,529      -2%   $82,024,556
# 31                      Mar 18-20   $80,060,996   -19.4%   $83,455,041
# 32                      Mar 11-13   $99,316,599   -39.2%  $101,939,737
# 33                        Mar 4-6  $163,405,808  +197.1%  $166,054,235
# 34                      Feb 25-27   $55,006,939     -39%   $60,894,360
# 35  Feb 18-21Presidents' Day wknd  $106,169,516  +784.3%  $111,431,414
# 36                      Feb 18-20   $90,159,064     +79%   $94,565,238
# 37                      Feb 11-13   $50,371,632    -9.8%   $53,803,427
# 38                        Feb 4-6   $55,860,817   +81.4%   $59,689,505
# 39                      Jan 28-30   $30,794,469     -27%   $34,885,910
# 40                      Jan 21-23   $42,161,017   -38.3%   $46,071,484
# 41                      Jan 14-16   $68,339,319   +13.3%   $71,534,496
# 42              Jan 14-17MLK wknd   $81,219,405  +549.9%   $85,074,757
# 43                        Jan 7-9   $60,318,053     -37%   $62,796,729
#
#     %± LW.1  Releases                                   #1 Release Genre  \
# 0         -        29                          Don't Worry Darling     -
# 1    +20.7%        69                               The Woman King     -
# 2      -24%        66                                    Barbarian     -
# 3      -49%        54                            Top Gun: Maverick     -
# 4     +6.7%        61                            Top Gun: Maverick     -
# 5    -33.9%        63                               The Invitation     -
# 6    +20.7%        57                Dragon Ball Super: Super Hero     -
# 7      -29%        63                                 Bullet Train     -
# 8     -5.9%        48                                 Bullet Train     -
# 9    -22.5%        53                      DC League of Super-Pets     -
# 10    -4.9%        52                                         Nope     -
# 11   -44.3%        54                       Thor: Love and Thunder     -
# 12   +25.5%        50                       Thor: Love and Thunder     -
# 13  +156.5%        40                     Minions: The Rise of Gru     -
# 14   +41.1%        53                     Minions: The Rise of Gru     -
# 15   -18.2%        54                                        Elvis     -
# 16   -23.4%        56                      Jurassic World Dominion     -
# 17   +76.6%        56                      Jurassic World Dominion     -
# 18   -31.3%        59                            Top Gun: Maverick     -
# 19  +128.2%        47                            Top Gun: Maverick     -
# 20  +134.2%        50                            Top Gun: Maverick     -
# 21   -17.5%        53  Doctor Strange in the Multiverse of Madness     -
# 22   -58.7%        49  Doctor Strange in the Multiverse of Madness     -
# 23  +232.3%        45  Doctor Strange in the Multiverse of Madness     -
# 24   -28.4%        50                                 The Bad Guys     -
# 25   -12.8%        46                                 The Bad Guys     -
# 26  +151.5%        30  Fantastic Beasts: The Secrets of Dumbledore     -
# 27    -9.7%        42  Fantastic Beasts: The Secrets of Dumbledore     -
# 28   +49.1%        50                         Sonic the Hedgehog 2     -
# 29    -2.9%        52                                      Morbius     -
# 30    -1.7%        59                                The Lost City     -
# 31   -18.1%        58                                   The Batman     -
# 32   -38.6%        53                                   The Batman     -
# 33  +172.7%        54                                   The Batman     -
# 34   -35.6%        53                                    Uncharted     -
# 35  +748.5%        50                                    Uncharted     -
# 36   +75.8%        51                                    Uncharted     -
# 37    -9.9%        51                            Death on the Nile     -
# 38   +71.1%        51                              Jackass Forever     -
# 39   -24.3%        47                      Spider-Man: No Way Home     -
# 40   -35.6%        44                      Spider-Man: No Way Home     -
# 41   +13.9%        41                                       Scream     -
# 42  +559.1%        37                                       Scream     -
# 43   -36.5%        35                      Spider-Man: No Way Home     -
#
#    Budget Running Time  Week  Long Weekend
# 0       -            -    38         False
# 1       -            -    37         False
# 2       -            -    36         False
# 3       -            -    35          True
# 4       -            -    35         False
# 5       -            -    34         False
# 6       -            -    33         False
# 7       -            -    32         False
# 8       -            -    31         False
# 9       -            -    30         False
# 10      -            -    29         False
# 11      -            -    28         False
# 12      -            -    27         False
# 13      -            -    26          True
# 14      -            -    26         False
# 15      -            -    25         False
# 16      -            -    24         False
# 17      -            -    23         False
# 18      -            -    22         False
# 19      -            -    21          True
# 20      -            -    21         False
# 21      -            -    20         False
# 22      -            -    19         False
# 23      -            -    18         False
# 24      -            -    17         False
# 25      -            -    16         False
# 26      -            -    15          True
# 27      -            -    15         False
# 28      -            -    14         False
# 29      -            -    13         False
# 30      -            -    12         False
# 31      -            -    11         False
# 32      -            -    10         False
# 33      -            -     9         False
# 34      -            -     8         False
# 35      -            -     7          True
# 36      -            -     7         False
# 37      -            -     6         False
# 38      -            -     5         False
# 39      -            -     4         False
# 40      -            -     3         False
# 41      -            -     2         False
# 42      -            -     2          True
# 43      -            -     1         False

# %%
df2019 = df[0]

# %% [markdown]
# ## Data cleaning

# %% [markdown]
# We can see that the table header is presented multiple times in several rows.

# %%
df2019[df2019.Budget == 'Budget']
# Out:
# Empty DataFrame
# Columns: [Dates, Top 10 Gross, %± LW, Overall Gross, %± LW.1, Releases, #1 Release, Genre, Budget, Running Time, Week, Long Weekend]
# Index: []

# %%
df2019.shape
# Out:
# (44, 12)

# %%
len(df2019[df2019.Budget == 'Budget'])
# Out:
# 0

# %%
df = df2019.drop(df2019[df2019.Budget == 'Budget'].index)

# %%
df.shape
# Out:
# (708, 30)

# %% [markdown]
# ## Quick Exploratory Data Analysis

# %%
import seaborn as sns

# %% [markdown]
# Making the histogram

# %%
sns.distplot(df.PTS, 
             kde=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-f1ead3704db3> in <module>
# ----> 1 sns.distplot(df.PTS,
#       2              kde=False)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'PTS'

# %% [markdown]
# Change bar line color

# %%
sns.distplot(df.PTS, 
             kde=False,
             hist_kws=dict(edgecolor="black", linewidth=2))

# %% [markdown]
# Change bar fill colors

# %%
sns.distplot(df.PTS,
             kde=False,
             hist_kws=dict(edgecolor="black", linewidth=2),
             color='#00BFC4')
